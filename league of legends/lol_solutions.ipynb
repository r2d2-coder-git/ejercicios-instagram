# %% [markdown]
# ### **CUÁL ES EL PERSONAJE TANQUE**
# ###
# ### **DEL LEAGUE OF LEGENDS**
# ###
# ### **MÁS DÍFICIL DE JUGAR**

# %%
import pandas as pd

df = pd.read_csv('lol_data.csv', index_col = 0)

df_tanques = df.loc[df['herotype'] == 'Tank']

df_ordenado = df_tanques.sort_values(by='difficulty', 
                                     ascending=False)

df_ordenado.head(1)
# Out:
#                    id     apiname                        title  difficulty  \
# K'Sante         897.0      KSante         the Pride of Nazumah           3
# Braum           201.0       Braum    the Heart of the Freljord           2
# Galio             3.0       Galio                 the Colossus           2
# Singed           27.0      Singed              the Mad Chemist           2
# Skarner          72.0     Skarner     the Primordial Sovereign           2
# Poppy            78.0       Poppy         Keeper of the Hammer           2
# Ornn            516.0        Ornn  The Fire below the Mountain           2
# Nautilus        111.0    Nautilus      the Titan of the Depths           2
# Sejuani         113.0     Sejuani            Fury of the North           2
# Shen             98.0        Shen          the Eye of Twilight           2
# Rell            526.0        Rell              the Iron Maiden           2
# Cho'Gath         31.0     Chogath       the Terror of the Void           1
# Alistar          12.0     Alistar                 the Minotaur           1
# Dr. Mundo        36.0     DrMundo           the Madman of Zaun           1
# Amumu            32.0       Amumu                the Sad Mummy           1
# Blitzcrank       53.0  Blitzcrank        the Great Steam Golem           1
# Rammus           33.0      Rammus               the Armordillo           1
# Nunu & Willump   20.0        Nunu         the Boy and His Yeti           1
# Malphite         54.0    Malphite        Shard of the Monolith           1
# Maokai           57.0      Maokai           the Twisted Treant           1
# Leona            89.0       Leona             the Radiant Dawn           1
# Sion             14.0        Sion        The Undead Juggernaut           1
# Tahm Kench      223.0   TahmKench               The River King           1
# Zac             154.0         Zac            the Secret Weapon           1
#
#                herotype  alttype resource  \
# K'Sante            Tank  Fighter     Mana
# Braum              Tank  Support     Mana
# Galio              Tank     Mage     Mana
# Singed             Tank     Mage     Mana
# Skarner            Tank  Fighter     Mana
# Poppy              Tank  Fighter     Mana
# Ornn               Tank  Fighter     Mana
# Nautilus           Tank  Support     Mana
# Sejuani            Tank  Fighter     Mana
# Shen               Tank      NaN   Energy
# Rell               Tank  Support     Mana
# Cho'Gath           Tank     Mage     Mana
# Alistar            Tank  Support     Mana
# Dr. Mundo          Tank  Fighter   Health
# Amumu              Tank  Support     Mana
# Blitzcrank         Tank  Support     Mana
# Rammus             Tank  Fighter     Mana
# Nunu & Willump     Tank     Mage     Mana
# Malphite           Tank     Mage     Mana
# Maokai             Tank  Support     Mana
# Leona              Tank  Support     Mana
# Sion               Tank  Fighter     Mana
# Tahm Kench         Tank  Support     Mana
# Zac                Tank  Fighter   Health
#
#                                                             stats rangetype  \
# K'Sante         {'hp_base': 625, 'hp_lvl': 120, 'mp_base': 320...     Melee
# Braum           {'hp_base': 610, 'hp_lvl': 112, 'mp_base': 311...     Melee
# Galio           {'hp_base': 632, 'hp_lvl': 126, 'mp_base': 410...     Melee
# Singed          {'hp_base': 650, 'hp_lvl': 99, 'mp_base': 330,...     Melee
# Skarner         {'hp_base': 630, 'hp_lvl': 110, 'mp_base': 320...     Melee
# Poppy           {'hp_base': 610, 'hp_lvl': 104, 'mp_base': 280...     Melee
# Ornn            {'hp_base': 660, 'hp_lvl': 109, 'mp_base': 341...     Melee
# Nautilus        {'hp_base': 646, 'hp_lvl': 100, 'mp_base': 400...     Melee
# Sejuani         {'hp_base': 630, 'hp_lvl': 114, 'mp_base': 400...     Melee
# Shen            {'hp_base': 610, 'hp_lvl': 99, 'mp_base': 400,...     Melee
# Rell            {'hp_base': 640, 'hp_lvl': 104, 'mp_base': 320...     Melee
# Cho'Gath        {'hp_base': 644, 'hp_lvl': 94, 'mp_base': 270,...     Melee
# Alistar         {'hp_base': 685, 'hp_lvl': 120, 'mp_base': 350...     Melee
# Dr. Mundo       {'hp_base': 613, 'hp_lvl': 103, 'mp_base': 0, ...     Melee
# Amumu           {'hp_base': 685, 'hp_lvl': 94, 'mp_base': 285,...     Melee
# Blitzcrank      {'hp_base': 600, 'hp_lvl': 109, 'mp_base': 267...     Melee
# Rammus          {'hp_base': 675, 'hp_lvl': 94, 'mp_base': 310,...     Melee
# Nunu & Willump  {'hp_base': 610, 'hp_lvl': 90, 'mp_base': 280,...     Melee
# Malphite        {'hp_base': 665, 'hp_lvl': 104, 'mp_base': 280...     Melee
# Maokai          {'hp_base': 665, 'hp_lvl': 109, 'mp_base': 375...     Melee
# Leona           {'hp_base': 646, 'hp_lvl': 101, 'mp_base': 302...     Melee
# Sion            {'hp_base': 655, 'hp_lvl': 87, 'mp_base': 400,...     Melee
# Tahm Kench      {'hp_base': 640, 'hp_lvl': 103, 'mp_base': 325...     Melee
# Zac             {'hp_base': 685, 'hp_lvl': 109, 'mp_base': 0, ...     Melee
#
#                       date  ...    be   rp  \
# K'Sante         2022-11-02  ...  4800  880
# Braum           2014-05-12  ...  3150  790
# Galio           2010-08-10  ...  3150  790
# Singed          2009-04-18  ...  4800  260
# Skarner         2011-08-09  ...  4800  880
# Poppy           2010-01-13  ...   450  260
# Ornn            2017-08-23  ...  4800  880
# Nautilus        2012-02-14  ...  4800  880
# Sejuani         2012-01-17  ...   450  260
# Shen            2010-03-24  ...  3150  790
# Rell            2020-12-10  ...  4800  880
# Cho'Gath        2009-06-26  ...  1350  585
# Alistar         2009-02-21  ...  1350  585
# Dr. Mundo       2009-09-02  ...   450  260
# Amumu           2009-06-26  ...   450  260
# Blitzcrank      2009-09-02  ...  1350  585
# Rammus          2009-07-10  ...  1350  585
# Nunu & Willump  2009-02-21  ...   450  260
# Malphite        2009-09-02  ...   450  260
# Maokai          2011-02-16  ...  4800  880
# Leona           2011-07-13  ...   450  260
# Sion            2009-02-21  ...  1350  585
# Tahm Kench      2015-07-09  ...  4800  880
# Zac             2013-03-29  ...  4800  880
#
#                                                        skill_i  \
# K'Sante                              {1: 'Dauntless Instinct'}
# Braum                                  {1: 'Concussive Blows'}
# Galio                                    {1: 'Colossal Smash'}
# Singed                               {1: 'Noxious Slipstream'}
# Skarner                            {1: 'Threads of Vibration'}
# Poppy           {1: 'Iron Ambassador', 2: 'Iron Ambassador 2'}
# Ornn                {1: 'Living Forge', 2: 'Master Craftsman'}
# Nautilus                                {1: 'Staggering Blow'}
# Sejuani                               {1: 'Fury of the North'}
# Shen                                         {1: 'Ki Barrier'}
# Rell                                     {1: 'Break the Mold'}
# Cho'Gath                                      {1: 'Carnivore'}
# Alistar                                 {1: 'Triumphant Roar'}
# Dr. Mundo                         {1: 'Goes Where He Pleases'}
# Amumu                                      {1: 'Cursed Touch'}
# Blitzcrank                                 {1: 'Mana Barrier'}
# Rammus                                     {1: 'Spiked Shell'}
# Nunu & Willump                     {1: 'Call of the Freljord'}
# Malphite                                 {1: 'Granite Shield'}
# Maokai                      {1: 'Sap Magic', 2: 'Sap Magic 2'}
# Leona                                          {1: 'Sunlight'}
# Sion                   {1: 'Glory in Death', 2: 'Death Surge'}
# Tahm Kench                            {1: 'An Acquired Taste'}
# Zac                 {1: 'Cell Division', 2: 'Cell Division 2'}
#
#                                                           skill_q  \
# K'Sante                                      {1: 'Ntofo Strikes'}
# Braum                                        {1: "Winter's Bite"}
# Galio                                         {1: 'Winds of War'}
# Singed                                        {1: 'Poison Trail'}
# Skarner                     {1: 'Shattered Earth', 2: 'Upheaval'}
# Poppy                                         {1: 'Hammer Shock'}
# Ornn                                      {1: 'Volcanic Rupture'}
# Nautilus                                       {1: 'Dredge Line'}
# Sejuani                                     {1: 'Arctic Assault'}
# Shen            {1: 'Twilight Assault', 2: 'Twilight Assault 2...
# Rell                                     {1: 'Shattering Strike'}
# Cho'Gath                                           {1: 'Rupture'}
# Alistar                                          {1: 'Pulverize'}
# Dr. Mundo                                 {1: 'Infected Bonesaw'}
# Amumu                                         {1: 'Bandage Toss'}
# Blitzcrank                                     {1: 'Rocket Grab'}
# Rammus                                           {1: 'Powerball'}
# Nunu & Willump                                     {1: 'Consume'}
# Malphite                                     {1: 'Seismic Shard'}
# Maokai                                       {1: 'Bramble Smash'}
# Leona                                   {1: 'Shield of Daybreak'}
# Sion                                      {1: 'Decimating Smash'}
# Tahm Kench                                     {1: 'Tongue Lash'}
# Zac                                     {1: 'Stretching Strikes'}
#
#                                                           skill_w  \
# K'Sante                                         {1: 'Path Maker'}
# Braum                                      {1: 'Stand Behind Me'}
# Galio            {1: 'Shield of Durand', 2: 'Shield of Durand 2'}
# Singed                                       {1: 'Mega Adhesive'}
# Skarner                                    {1: 'Seismic Bastion'}
# Poppy           {1: 'Steadfast Presence', 2: 'Stubborn to a Fa...
# Ornn                                        {1: 'Bellows Breath'}
# Nautilus                                     {1: "Titan's Wrath"}
# Sejuani                                     {1: "Winter's Wrath"}
# Shen                                       {1: "Spirit's Refuge"}
# Rell            {1: 'Ferromancy: Crash Down', 2: 'Ferromancy: ...
# Cho'Gath                                      {1: 'Feral Scream'}
# Alistar                                           {1: 'Headbutt'}
# Dr. Mundo                                     {1: 'Heart Zapper'}
# Amumu                                              {1: 'Despair'}
# Blitzcrank                                       {1: 'Overdrive'}
# Rammus                                 {1: 'Defensive Ball Curl'}
# Nunu & Willump                      {1: 'Biggest Snowball Ever!'}
# Malphite                                       {1: 'Thunderclap'}
# Maokai                                     {1: 'Twisted Advance'}
# Leona                                              {1: 'Eclipse'}
# Sion                     {1: 'Soul Furnace', 2: 'Soul Furnace 2'}
# Tahm Kench                                    {1: 'Abyssal Dive'}
# Zac                                        {1: 'Unstable Matter'}
#
#                                   skill_e  \
# K'Sante                   {1: 'Footwork'}
# Braum                  {1: 'Unbreakable'}
# Galio                {1: 'Justice Punch'}
# Singed                       {1: 'Fling'}
# Skarner             {1: "Ixtal's Impact"}
# Poppy                {1: 'Heroic Charge'}
# Ornn                {1: 'Searing Charge'}
# Nautilus                   {1: 'Riptide'}
# Sejuani                 {1: 'Permafrost'}
# Shen                   {1: 'Shadow Dash'}
# Rell                     {1: 'Full Tilt'}
# Cho'Gath             {1: 'Vorpal Spikes'}
# Alistar                    {1: 'Trample'}
# Dr. Mundo       {1: 'Blunt Force Trauma'}
# Amumu                      {1: 'Tantrum'}
# Blitzcrank              {1: 'Power Fist'}
# Rammus             {1: 'Frenzying Taunt'}
# Nunu & Willump    {1: 'Snowball Barrage'}
# Malphite               {1: 'Ground Slam'}
# Maokai                {1: 'Sapling Toss'}
# Leona                 {1: 'Zenith Blade'}
# Sion            {1: 'Roar of the Slayer'}
# Tahm Kench              {1: 'Thick Skin'}
# Zac              {1: 'Elastic Slingshot'}
#
#                                                           skill_r  \
# K'Sante                                            {1: 'All Out'}
# Braum                                      {1: 'Glacial Fissure'}
# Galio                                      {1: "Hero's Entrance"}
# Singed                                     {1: 'Insanity Potion'}
# Skarner                                             {1: 'Impale'}
# Poppy                                     {1: "Keeper's Verdict"}
# Ornn                                 {1: 'Call of the Forge God'}
# Nautilus                 {1: 'Depth Charge', 2: 'Depth Charge 2'}
# Sejuani                                     {1: 'Glacial Prison'}
# Shen                     {1: 'Stand United', 2: 'Stand United 2'}
# Rell                                          {1: 'Magnet Storm'}
# Cho'Gath                                             {1: 'Feast'}
# Alistar                                   {1: 'Unbreakable Will'}
# Dr. Mundo                                   {1: 'Maximum Dosage'}
# Amumu                               {1: 'Curse of the Sad Mummy'}
# Blitzcrank                                    {1: 'Static Field'}
# Rammus                                        {1: 'Soaring Slam'}
# Nunu & Willump                               {1: 'Absolute Zero'}
# Malphite                                 {1: 'Unstoppable Force'}
# Maokai                                      {1: "Nature's Grasp"}
# Leona                                          {1: 'Solar Flare'}
# Sion            {1: 'Unstoppable Onslaught', 2: 'Unstoppable O...
# Tahm Kench                        {1: 'Devour', 2: 'Regurgitate'}
# Zac                                          {1: "Let's Bounce!"}
#
#                                                            skills  \
# K'Sante         {1: 'Dauntless Instinct', 2: 'Ntofo Strikes', ...
# Braum           {1: 'Concussive Blows', 2: "Winter's Bite", 3:...
# Galio           {1: 'Colossal Smash', 2: 'Winds of War', 3: 'S...
# Singed          {1: 'Noxious Slipstream', 2: 'Poison Trail', 3...
# Skarner         {1: 'Threads of Vibration', 2: 'Shattered Eart...
# Poppy           {1: 'Iron Ambassador', 2: 'Hammer Shock', 3: '...
# Ornn            {1: 'Living Forge', 2: 'Master Craftsman', 3: ...
# Nautilus        {1: 'Staggering Blow', 2: 'Dredge Line', 3: "T...
# Sejuani         {1: 'Fury of the North', 2: 'Arctic Assault', ...
# Shen            {1: 'Ki Barrier', 2: 'Twilight Assault', 3: "S...
# Rell            {1: 'Break the Mold', 2: 'Shattering Strike', ...
# Cho'Gath        {1: 'Carnivore', 2: 'Rupture', 3: 'Feral Screa...
# Alistar         {1: 'Triumphant Roar', 2: 'Pulverize', 3: 'Hea...
# Dr. Mundo       {1: 'Goes Where He Pleases', 2: 'Infected Bone...
# Amumu           {1: 'Cursed Touch', 2: 'Bandage Toss', 3: 'Des...
# Blitzcrank      {1: 'Mana Barrier', 2: 'Rocket Grab', 3: 'Over...
# Rammus          {1: 'Spiked Shell', 2: 'Powerball', 3: 'Defens...
# Nunu & Willump  {1: 'Call of the Freljord', 2: 'Consume', 3: '...
# Malphite        {1: 'Granite Shield', 2: 'Seismic Shard', 3: '...
# Maokai          {1: 'Sap Magic', 2: 'Bramble Smash', 3: 'Twist...
# Leona           {1: 'Sunlight', 2: 'Shield of Daybreak', 3: 'E...
# Sion            {1: 'Glory in Death', 2: 'Death Surge', 3: 'De...
# Tahm Kench      {1: 'An Acquired Taste', 2: 'Tongue Lash', 3: ...
# Zac             {1: 'Cell Division', 2: 'Stretching Strikes', ...
#
#                       fullname                          nickname
# K'Sante                    NaN                               NaN
# Braum                      NaN                               NaN
# Galio                      NaN                               NaN
# Singed                     NaN                               NaN
# Skarner                    NaN                               NaN
# Poppy                      NaN                               NaN
# Ornn                       NaN                               NaN
# Nautilus                   NaN                               NaN
# Sejuani                    NaN                               NaN
# Shen                       NaN                               NaN
# Rell                       NaN            Darkrider, DarkSupport
# Cho'Gath                   NaN                               NaN
# Alistar                    NaN                               NaN
# Dr. Mundo       'Doctor' Mundo                               NaN
# Amumu                      NaN                               NaN
# Blitzcrank                 NaN                               NaN
# Rammus                     NaN                               NaN
# Nunu & Willump  Nunu & Willump                               NaN
# Malphite                   NaN                               NaN
# Maokai                     NaN                               NaN
# Leona                      NaN                               NaN
# Sion                       NaN                               NaN
# Tahm Kench                 NaN                               NaN
# Zac                        NaN  Zaun Amorphous Combatant, Z.A.C.
#
# [24 rows x 32 columns]
