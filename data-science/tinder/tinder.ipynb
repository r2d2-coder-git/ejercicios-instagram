# %% [markdown]
# #### **CALCULA EL PORCENTAJE**
# #### **DE PERSONAS QUE**
# #### **CONSIGUIERON PAREJA**
# #### **EN TINDER**

# %%
import pandas as pd

df = pd.read_csv("encuestas_tinder.csv")

# %%
condicion_pareja = (df['Answer'] == 'Yes') \
                    & (df['It became a Relationship'] == 'Yes')

parejas_tinder = df.loc[condicion_pareja]

porcentaje = (len(parejas_tinder) / len(df) * 100).__round__(2)

print(f"El porcentaje de parejas es {porcentaje} %")

# %% [markdown]
# #### **¿QUÉ GENERO CONSIGUE MAS PAREJAS EN TINDER?**

# %%
import pandas as pd

df = pd.read_csv("encuestas_tinder.csv")

condicion_pareja = (df['Answer'] == 'Yes') \
                    & (df['It became a Relationship'] == 'Yes')

parejas_tinder = df.loc[condicion_pareja]

conteo_genero = (parejas_tinder['Gender'].value_counts() \
                  / len(parejas_tinder) * 100)

conteo_genero
# Out:
# Gender
# female    63.636364
# male      36.363636
# Name: count, dtype: float64
